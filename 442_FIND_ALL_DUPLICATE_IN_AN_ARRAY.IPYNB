# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def findDuplicates(self, nums: List[int]) -> List[int]:
        s = set(nums)
        for i in nums:
            if i in s:
                s.remove(i)
            else:
                s.add(i)
        
        return list(s)
